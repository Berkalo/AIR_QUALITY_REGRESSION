# %%
import pandas as pd
import matplotlib.pyplot as pyplot
import pickle
#read, and prepare data
from matplotlib import style

# %%
df = pd.read_excel("AirQualityUCI.xlsx")
df.head()
print(list(df.columns))
df
# Out:
# ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6  1360.000000       150  11.881723
# 1    2004-03-10  19:00:00     2.0  1292.250000       112   9.397165
# 2    2004-03-10  20:00:00     2.2  1402.000000        88   8.997817
# 3    2004-03-10  21:00:00     2.2  1375.500000        80   9.228796
# 4    2004-03-10  22:00:00     1.6  1272.250000        51   6.518224
# 5    2004-03-10  23:00:00     1.2  1197.000000        38   4.741012
# 6    2004-03-11  00:00:00     1.2  1185.000000        31   3.624399
# 7    2004-03-11  01:00:00     1.0  1136.250000        31   3.326677
# 8    2004-03-11  02:00:00     0.9  1094.000000        24   2.339416
# 9    2004-03-11  03:00:00     0.6  1009.750000        19   1.696658
# ...

# %%
df = df.drop(columns = list(df.columns)[-2:], axis = 1)

# %%
df = df.dropna()

# %%
df.dtypes
# Out:
# Date             datetime64[ns]
# Time                     object
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                  int64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# dtype: object

# %%
Data_f = df[['Date', "CO(GT)","NOx(GT)","NO2(GT)","T"]]

# %%
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6  1360.000000       150  11.881723
# 1    2004-03-10  19:00:00     2.0  1292.250000       112   9.397165
# 2    2004-03-10  20:00:00     2.2  1402.000000        88   8.997817
# 3    2004-03-10  21:00:00     2.2  1375.500000        80   9.228796
# 4    2004-03-10  22:00:00     1.6  1272.250000        51   6.518224
# 5    2004-03-10  23:00:00     1.2  1197.000000        38   4.741012
# 6    2004-03-11  00:00:00     1.2  1185.000000        31   3.624399
# 7    2004-03-11  01:00:00     1.0  1136.250000        31   3.326677
# 8    2004-03-11  02:00:00     0.9  1094.000000        24   2.339416
# 9    2004-03-11  03:00:00     0.6  1009.750000        19   1.696658
# 10   2004-03-11  04:00:00  -200.0  1011.000000        14   1.293620
# 11   2004-03-11  05:00:00     0.7  1066.000000         8   1.133431
# 12   2004-03-11  06:00:00     0.7  1051.750000        16   1.603768
# ...

# %%
Data_f.iloc[:,0] = pd.to_numeric(Data_f.iloc[:,0]) 
Data_f =Data_f[Data_f > 0]
Data_f= Data_f.dropna()
Data_f.iloc[:,0] = pd.to_datetime(Data_f.iloc[:,0])

# %%
Data_f
# Out:
#            Date  CO(GT)  NOx(GT)  NO2(GT)          T
# 0    2004-03-10     2.6    166.0    113.0  13.600000
# 1    2004-03-10     2.0    103.0     92.0  13.300000
# 2    2004-03-10     2.2    131.0    114.0  11.900000
# 3    2004-03-10     2.2    172.0    122.0  11.000000
# 4    2004-03-10     1.6    131.0    116.0  11.150000
# 5    2004-03-10     1.2     89.0     96.0  11.175000
# 6    2004-03-11     1.2     62.0     77.0  11.325000
# 7    2004-03-11     1.0     62.0     76.0  10.675000
# 8    2004-03-11     0.9     45.0     60.0  10.650000
# 11   2004-03-11     0.7     16.0     28.0  11.000000
# 12   2004-03-11     0.7     34.0     48.0  10.450000
# 13   2004-03-11     1.1     98.0     82.0  10.200000
# 14   2004-03-11     2.0    174.0    112.0  10.750000
# 15   2004-03-11     2.2    129.0    101.0  10.500000
# 16   2004-03-11     1.7    112.0     98.0  10.800000
# 17   2004-03-11     1.5     95.0     92.0  10.500000
# 18   2004-03-11     1.6    104.0     95.0   9.525000
# ...

# %%
Data_f = Data_f.set_index('Date').groupby(pd.Grouper(freq='D')).mean().dropna()

# %%
Data_f.shape
# Out:
# (44, 11)

# %%
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer

df = pd.read_excel(r'AirQualityUCI.xlsx')

print(df.head())
print(list(df.columns))
print(df.dtypes)

df = df.drop(columns=list(df.columns)[-2:], axis=1)
y_ = [a for a in range(9357)]
Data_f = df[["CO(GT)", "NOx(GT)", "NO2(GT)", "T"]];

print(list(Data_f.shape)[1])

DATA = Data_f.values

print(Data_f.describe())

y_ = np.array(Data_f[["T"]].values)
X = np.array(Data_f[["CO(GT)", "NOx(GT)", "NO2(GT)"]])
#y_ = [a for a in range(9357)]
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y_, test_size=0.1)
print(y_)

print(df[df < 0])
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...
